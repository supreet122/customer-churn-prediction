# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/telco.csv')

# %%
print("Rows and Columns",df.shape)
# Out:
# Rows and Columns (7043, 50)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Churn Reason                         5174
# Churn Category                       5174
# Offer                                3877
# Internet Type                        1526
# Senior Citizen                          0
# Married                                 0
# Age                                     0
# Under 30                                0
# Country                                 0
# State                                   0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Dependents                              0
# Number of Dependents                    0
# Customer ID                             0
# Gender                                  0
# Number of Referrals                     0
# Referred a Friend                       0
# Quarter                                 0
# Population                              0
# Avg Monthly Long Distance Charges       0
# Multiple Lines                          0
# Phone Service                           0
# Tenure in Months                        0
# Online Security                         0
# Online Backup                           0
# Device Protection Plan                  0
# Premium Tech Support                    0
# Streaming TV                            0
# Streaming Movies                        0
# Internet Service                        0
# Avg Monthly GB Download                 0
# Unlimited Data                          0
# Streaming Music                         0
# Contract                                0
# Paperless Billing                       0
# Total Charges                           0
# Total Refunds                           0
# Payment Method                          0
# Monthly Charge                          0
# Total Long Distance Charges             0
# Total Extra Data Charges                0
# Total Revenue                           0
# Satisfaction Score                      0
# Churn Label                             0
# Customer Status                         0
# CLTV                                    0
# Churn Score                             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df["Customer ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
columns_to_drop = [
    "Customer ID",
    "Churn Score",
    "Churn Category",
    "Churn Reason",
    "Customer Status",
    "CLTV",
    "Total Revenue"
]

df.drop(columns=columns_to_drop, inplace=True)

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Under 30', 'Senior Citizen', 'Married', 'Dependents',
#        'Number of Dependents', 'Country', 'State', 'City', 'Zip Code',
#        'Latitude', 'Longitude', 'Population', 'Quarter', 'Referred a Friend',
#        'Number of Referrals', 'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Satisfaction Score', 'Churn Label'],
#       dtype='str')

# %%
for col in df.columns:
    print(col,":",df[col].nunique)
# Out:
# Gender : <bound method IndexOpsMixin.nunique of 0         Male
# 1       Female
# 2         Male
# 3       Female
# 4       Female
#          ...
# 7038    Female
# 7039      Male
# 7040    Female
# 7041    Female
# 7042      Male
# Name: Gender, Length: 7043, dtype: str>
# Age : <bound method IndexOpsMixin.nunique of 0       78
# 1       74
# 2       71
# 3       78
# 4       80
#         ..
# 7038    30
# 7039    38
# 7040    30
# 7041    32
# 7042    44
# Name: Age, Length: 7043, dtype: int64>
# Under 30 : <bound method IndexOpsMixin.nunique of 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#         ..
# 7038    No
# 7039    No
# 7040    No
# 7041    No
# 7042    No
# Name: Under 30, Length: 7043, dtype: str>
# Senior Citizen : <bound method IndexOpsMixin.nunique of 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041     No
# 7042     No
# Name: Senior Citizen, Length: 7043, dtype: str>
# Married : <bound method IndexOpsMixin.nunique of 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 7038     No
# 7039    Yes
# 7040    Yes
# 7041    Yes
# 7042     No
# Name: Married, Length: 7043, dtype: str>
# Dependents : <bound method IndexOpsMixin.nunique of 0        No
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7038     No
# 7039    Yes
# 7040    Yes
# 7041    Yes
# 7042     No
# Name: Dependents, Length: 7043, dtype: str>
# Number of Dependents : <bound method IndexOpsMixin.nunique of 0       0
# 1       1
# 2       3
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    2
# 7040    2
# 7041    2
# 7042    0
# Name: Number of Dependents, Length: 7043, dtype: int64>
# Country : <bound method IndexOpsMixin.nunique of 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4       United States
#             ...
# 7038    United States
# 7039    United States
# 7040    United States
# 7041    United States
# 7042    United States
# Name: Country, Length: 7043, dtype: str>
# State : <bound method IndexOpsMixin.nunique of 0       California
# 1       California
# 2       California
# 3       California
# 4       California
#            ...
# 7038    California
# 7039    California
# 7040    California
# 7041    California
# 7042    California
# Name: State, Length: 7043, dtype: str>
# City : <bound method IndexOpsMixin.nunique of 0        Los Angeles
# 1        Los Angeles
# 2        Los Angeles
# 3          Inglewood
# 4           Whittier
#             ...
# 7038         Landers
# 7039        Adelanto
# 7040           Amboy
# 7041    Angelus Oaks
# 7042    Apple Valley
# Name: City, Length: 7043, dtype: str>
# Zip Code : <bound method IndexOpsMixin.nunique of 0       90022
# 1       90063
# 2       90065
# 3       90303
# 4       90602
#         ...
# 7038    92285
# 7039    92301
# 7040    92304
# 7041    92305
# 7042    92308
# Name: Zip Code, Length: 7043, dtype: int64>
# Latitude : <bound method IndexOpsMixin.nunique of 0       34.023810
# 1       34.044271
# 2       34.108833
# 3       33.936291
# 4       33.972119
#           ...
# 7038    34.341737
# 7039    34.667815
# 7040    34.559882
# 7041    34.167800
# 7042    34.424926
# Name: Latitude, Length: 7043, dtype: float64>
# Longitude : <bound method IndexOpsMixin.nunique of 0      -118.156582
# 1      -118.185237
# 2      -118.229715
# 3      -118.332639
# 4      -118.020188
#            ...
# 7038   -116.539416
# 7039   -117.536183
# 7040   -115.637164
# 7041   -116.864330
# 7042   -117.184503
# Name: Longitude, Length: 7043, dtype: float64>
# Population : <bound method IndexOpsMixin.nunique of 0       68701
# 1       55668
# 2       47534
# 3       27778
# 4       26265
#         ...
# 7038     2182
# 7039    18980
# 7040       42
# 7041      301
# 7042    28819
# Name: Population, Length: 7043, dtype: int64>
# Quarter : <bound method IndexOpsMixin.nunique of 0       Q3
# 1       Q3
# 2       Q3
# 3       Q3
# 4       Q3
#         ..
# 7038    Q3
# 7039    Q3
# 7040    Q3
# 7041    Q3
# 7042    Q3
# Name: Quarter, Length: 7043, dtype: str>
# Referred a Friend : <bound method IndexOpsMixin.nunique of 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 7038     No
# 7039    Yes
# 7040    Yes
# 7041    Yes
# 7042     No
# Name: Referred a Friend, Length: 7043, dtype: str>
# Number of Referrals : <bound method IndexOpsMixin.nunique of 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    1
# 7040    4
# 7041    1
# 7042    0
# Name: Number of Referrals, Length: 7043, dtype: int64>
# Tenure in Months : <bound method IndexOpsMixin.nunique of 0        1
# 1        8
# 2       18
# 3       25
# 4       37
#         ..
# 7038    72
# 7039    24
# 7040    72
# 7041    11
# 7042    66
# Name: Tenure in Months, Length: 7043, dtype: int64>
# Offer : <bound method IndexOpsMixin.nunique of 0           NaN
# 1       Offer E
# 2       Offer D
# 3       Offer C
# 4       Offer C
#          ...
# 7038        NaN
# 7039    Offer C
# 7040        NaN
# 7041        NaN
# 7042        NaN
# Name: Offer, Length: 7043, dtype: str>
# Phone Service : <bound method IndexOpsMixin.nunique of 0        No
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042    Yes
# Name: Phone Service, Length: 7043, dtype: str>
# Avg Monthly Long Distance Charges : <bound method IndexOpsMixin.nunique of 0        0.00
# 1       48.85
# 2       11.33
# 3       19.76
# 4        6.33
#         ...
# 7038    22.77
# 7039    36.05
# 7040    29.66
# 7041     0.00
# 7042    30.96
# Name: Avg Monthly Long Distance Charges, Length: 7043, dtype: float64>
# Multiple Lines : <bound method IndexOpsMixin.nunique of 0        No
# 1       Yes
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042     No
# Name: Multiple Lines, Length: 7043, dtype: str>
# Internet Service : <bound method IndexOpsMixin.nunique of 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7038     No
# 7039    Yes
# 7040    Yes
# 7041    Yes
# 7042    Yes
# Name: Internet Service, Length: 7043, dtype: str>
# Internet Type : <bound method IndexOpsMixin.nunique of 0               DSL
# 1       Fiber Optic
# 2       Fiber Optic
# 3       Fiber Optic
# 4       Fiber Optic
#            ...
# 7038            NaN
# 7039          Cable
# 7040    Fiber Optic
# 7041            DSL
# 7042    Fiber Optic
# Name: Internet Type, Length: 7043, dtype: str>
# Avg Monthly GB Download : <bound method IndexOpsMixin.nunique of 0        8
# 1       17
# 2       52
# 3       12
# 4       14
#         ..
# 7038     0
# 7039    24
# 7040    59
# 7041    17
# 7042    11
# Name: Avg Monthly GB Download, Length: 7043, dtype: int64>
# Online Security : <bound method IndexOpsMixin.nunique of 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038     No
# 7039    Yes
# 7040     No
# 7041    Yes
# 7042    Yes
# Name: Online Security, Length: 7043, dtype: str>
# Online Backup : <bound method IndexOpsMixin.nunique of 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4        No
#        ...
# 7038     No
# 7039     No
# 7040    Yes
# 7041     No
# 7042     No
# Name: Online Backup, Length: 7043, dtype: str>
# Device Protection Plan : <bound method IndexOpsMixin.nunique of 0       Yes
# 1        No
# 2        No
# 3       Yes
# 4        No
#        ...
# 7038     No
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042    Yes
# Name: Device Protection Plan, Length: 7043, dtype: str>
# Premium Tech Support : <bound method IndexOpsMixin.nunique of 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038     No
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: Premium Tech Support, Length: 7043, dtype: str>
# Streaming TV : <bound method IndexOpsMixin.nunique of 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 7038     No
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042    Yes
# Name: Streaming TV, Length: 7043, dtype: str>
# Streaming Movies : <bound method IndexOpsMixin.nunique of 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 7038     No
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042    Yes
# Name: Streaming Movies, Length: 7043, dtype: str>
# Streaming Music : <bound method IndexOpsMixin.nunique of 0        No
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 7038     No
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042    Yes
# Name: Streaming Music, Length: 7043, dtype: str>
# Unlimited Data : <bound method IndexOpsMixin.nunique of 0        No
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7038     No
# 7039    Yes
# 7040    Yes
# 7041    Yes
# 7042    Yes
# Name: Unlimited Data, Length: 7043, dtype: str>
# Contract : <bound method IndexOpsMixin.nunique of 0       Month-to-Month
# 1       Month-to-Month
# 2       Month-to-Month
# 3       Month-to-Month
# 4       Month-to-Month
#              ...
# 7038          Two Year
# 7039          One Year
# 7040          One Year
# 7041    Month-to-Month
# 7042          Two Year
# Name: Contract, Length: 7043, dtype: str>
# Paperless Billing : <bound method IndexOpsMixin.nunique of 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041    Yes
# 7042    Yes
# Name: Paperless Billing, Length: 7043, dtype: str>
# Payment Method : <bound method IndexOpsMixin.nunique of 0       Bank Withdrawal
# 1           Credit Card
# 2       Bank Withdrawal
# 3       Bank Withdrawal
# 4       Bank Withdrawal
#              ...
# 7038    Bank Withdrawal
# 7039       Mailed Check
# 7040        Credit Card
# 7041    Bank Withdrawal
# 7042    Bank Withdrawal
# Name: Payment Method, Length: 7043, dtype: str>
# Monthly Charge : <bound method IndexOpsMixin.nunique of 0        39.65
# 1        80.65
# 2        95.45
# 3        98.50
# 4        76.50
#          ...
# 7038     21.15
# 7039     84.80
# 7040    103.20
# 7041     29.60
# 7042    105.65
# Name: Monthly Charge, Length: 7043, dtype: float64>
# Total Charges : <bound method IndexOpsMixin.nunique of 0         39.65
# 1        633.30
# 2       1752.55
# 3       2514.50
# 4       2868.15
#          ...
# 7038    1419.40
# 7039    1990.50
# 7040    7362.90
# 7041     346.45
# 7042    6844.50
# Name: Total Charges, Length: 7043, dtype: float64>
# Total Refunds : <bound method IndexOpsMixin.nunique of 0        0.00
# 1        0.00
# 2       45.61
# 3       13.43
# 4        0.00
#         ...
# 7038    19.31
# 7039    48.23
# 7040    45.38
# 7041    27.24
# 7042     0.00
# Name: Total Refunds, Length: 7043, dtype: float64>
# Total Extra Data Charges : <bound method IndexOpsMixin.nunique of 0       20
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 7038     0
# 7039     0
# 7040     0
# 7041     0
# 7042     0
# Name: Total Extra Data Charges, Length: 7043, dtype: int64>
# Total Long Distance Charges : <bound method IndexOpsMixin.nunique of 0          0.00
# 1        390.80
# 2        203.94
# 3        494.00
# 4        234.21
#          ...
# 7038    1639.44
# 7039     865.20
# 7040    2135.52
# 7041       0.00
# 7042    2043.36
# Name: Total Long Distance Charges, Length: 7043, dtype: float64>
# Satisfaction Score : <bound method IndexOpsMixin.nunique of 0       3
# 1       3
# 2       2
# 3       2
# 4       2
#        ..
# 7038    5
# 7039    3
# 7040    4
# 7041    4
# 7042    4
# Name: Satisfaction Score, Length: 7043, dtype: int64>
# Churn Label : <bound method IndexOpsMixin.nunique of 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041     No
# 7042     No
# Name: Churn Label, Length: 7043, dtype: str>

# %%
df.dtypes
# Out:
# Gender                                   str
# Age                                    int64
# Under 30                                 str
# Senior Citizen                           str
# Married                                  str
# Dependents                               str
# Number of Dependents                   int64
# Country                                  str
# State                                    str
# City                                     str
# Zip Code                               int64
# Latitude                             float64
# Longitude                            float64
# Population                             int64
# Quarter                                  str
# Referred a Friend                        str
# Number of Referrals                    int64
# Tenure in Months                       int64
# Offer                                    str
# Phone Service                            str
# Avg Monthly Long Distance Charges    float64
# Multiple Lines                           str
# Internet Service                         str
# Internet Type                            str
# Avg Monthly GB Download                int64
# Online Security                          str
# Online Backup                            str
# Device Protection Plan                   str
# Premium Tech Support                     str
# Streaming TV                             str
# Streaming Movies                         str
# Streaming Music                          str
# Unlimited Data                           str
# Contract                                 str
# Paperless Billing                        str
# Payment Method                           str
# Monthly Charge                       float64
# Total Charges                        float64
# Total Refunds                        float64
# Total Extra Data Charges               int64
# Total Long Distance Charges          float64
# Satisfaction Score                     int64
# Churn Label                              str
# dtype: object

# %%
df["Churn Label"].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn Label"].value_counts(normalize=True) * 100
# Out:
# Churn Label
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
df.to_csv("../data/telco_clean.csv",index=False)

# %%
# Data Cleaning Summary
# Loaded dataset successfully.
# Checked missing values.
# Removed duplicate rows (if any).
# Removed data leakage columns.
# Removed Customer ID.
# Checked constant columns.
# Verified target variable.
#Saved cleaned dataset.
